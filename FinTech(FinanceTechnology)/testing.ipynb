# %%
import numpy as np
import pandas as pd

# %%
https://www.facebook.com/Sunniyouthparliament/photos/pcb.2235412806694149/2235412610027502/?type=3

# %%
np.random.randn(1000,4)+0.5
# Out:
# array([[ 1.14152823, -0.08285859,  0.26983224,  0.35670765],
#        [ 1.71595191,  1.90200235,  0.78813987, -1.56401764],
#        [-0.81100299,  0.74000021,  0.56043122,  0.99767842],
#        ...,
#        [ 1.30311471,  0.14688897,  1.97463199,  0.05573548],
#        [ 0.84159125,  1.41470118,  0.88561408,  0.02419749],
#        [ 0.03512718,  1.70190807,  0.13218313,  0.16599923]])

# %%
import pandas_datareader as web

from pandas_datareader import data, web
# define data to be downloaded
tickers = list(pd.read_csv('./data/SP100_LIST.csv', sep=';')['Symbol'])
print(tickers)
provider = 'yahoo'
start = '2010-01-01'
end = '2017-11-14'
 
# download data
#data = web.DataReader(tickers, provider, start)['Adj Close']
#print(data)


data=pd.read_csv('./data/data_sp100.csv', sep=';')
 
# read data from file
data = pd.read_csv('./data/data_sp100.csv', sep=';', index_col=0, header=0, parse_dates=True)
print(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-56ba8158702b> in <module>()
#       1 import pandas_datareader as web
#       2
# ----> 3 from pandas_datareader import data, web
#       4 # define data to be downloaded
#       5 tickers = list(pd.read_csv('./data/SP100_LIST.csv', sep=';')['Symbol'])
#
# ImportError: cannot import name 'web'

# %%
import numpy as np
x,y = np.loadtxt('data/SP100_LIST.csv', usecols=(0,1), delimiter=';' ,unpack=True, dtype='str')
x

# %%
import pandas_datareader as web
# define data to be downloaded
tickers = list(pd.read_csv('./data/SP100_LIST.csv', sep=';')['Symbol'])
print(tickers)
provider = 'google'
start = '2010-01-01'
end = '2017-11-14'
 
# download data
data = web.DataReader(tickers, provider, start)['Adj Close']
#read data 

#data=pd.read_csv('./data/data_sp100.csv', sep=';')
 
# read data from file
data = pd.read_csv('./data/data_sp100.csv', sep=';', index_col=0, header=0, parse_dates=True)
print(data)

# %%
#from pandas.iimport pandas_datareader.data as webo import data, wb # becomes
from pandas_datareader import data, wb

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2015, 1, 27)
f = web.DataReader('F', 'google', start, end)
f
# Out:
# C:\Users\Muhammad Qasim\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
#              Open   High    Low  Close     Volume
# Date
# 2010-01-04  10.17  10.28  10.05  10.28   60855796
# 2010-01-05  10.45  11.24  10.40  10.96  215620138
# 2010-01-06  11.21  11.46  11.13  11.37  200070554
# 2010-01-07  11.46  11.69  11.32  11.66  130201626
# 2010-01-08  11.67  11.74  11.46  11.69  130462912
# 2010-01-11  11.90  12.14  11.78  12.11  170626174
# 2010-01-12  11.98  12.03  11.72  11.87  162995898
# 2010-01-13  11.91  11.93  11.47  11.68  154527028
# 2010-01-14  11.65  11.86  11.51  11.76  116572673
# 2010-01-15  11.74  11.76  11.55  11.60   96174717
# 2010-01-19  11.51  11.83  11.46  11.75   65933944
# 2010-01-20  11.68  11.69  11.50  11.51   71649459
# 2010-01-21  11.53  11.62  11.01  11.18  121451396
# 2010-01-22  11.01  11.12  10.41  10.52  161530010
# 2010-01-25  10.73  11.10  10.61  11.03  121621423
# 2010-01-26  11.17  11.46  11.07  11.19  108250462
# 2010-01-27  11.57  11.62  11.22  11.55  105091531
# 2010-01-28  11.90  11.95  11.27  11.41  203466724
# 2010-01-29  11.60  11.61  10.70  10.84  159741164
# 2010-02-01  11.14  11.18  10.93  11.12   82748130
# 2010-02-02  11.26  11.52  11.19  11.39  119785377
# 2010-02-03  11.49  11.66  11.42  11.64   90125495
# 2010-02-04  11.49  11.53  11.00  11.06  129792142
# 2010-02-05  10.97  11.11  10.49  10.91  181535182
# 2010-02-08  11.09  11.32  10.88  10.97   92031327
# 2010-02-09  11.18  11.22  11.02  11.15   83207091
# 2010-02-10  11.12  11.14  10.90  10.94   73395561
# 2010-02-11  11.00  11.18  10.88  11.18   65116156
# 2010-02-12  10.92  11.18  10.85  11.12   69465400
# 2010-02-16  11.21  11.38  11.11  11.32   62537480
# ...           ...    ...    ...    ...        ...
# 2014-12-12  15.20  15.21  14.99  14.99   22684527
# 2014-12-15  14.86  14.92  14.27  14.28   47476393
# 2014-12-16  14.19  14.46  13.93  14.09   43879326
# 2014-12-17  14.17  14.52  14.11  14.45   29504188
# 2014-12-18  14.70  14.81  14.51  14.81   35542480
# 2014-12-19  14.79  15.05  14.74  15.03   40843451
# 2014-12-22  15.08  15.24  15.00  15.22   25366758
# 2014-12-23  15.21  15.45  15.21  15.33   20828661
# 2014-12-24  15.37  15.38  15.25  15.30    7128841
# 2014-12-26  15.30  15.48  15.26  15.45   11666422
# 2014-12-29  15.37  15.68  15.34  15.52   19137473
# 2014-12-30  15.48  15.60  15.44  15.50   14795048
# 2014-12-31  15.51  15.64  15.47  15.50   17930162
# 2015-01-02  15.59  15.65  15.18  15.36   24777911
# 2015-01-05  15.12  15.13  14.69  14.76   44079745
# 2015-01-06  14.88  14.90  14.38  14.62   32981627
# 2015-01-07  14.78  15.09  14.77  15.04   26065329
# 2015-01-08  15.40  15.48  15.23  15.42   33943398
# 2015-01-09  15.46  15.47  15.06  15.21   23420750
# 2015-01-12  15.31  15.32  15.11  15.22   22750784
# 2015-01-13  15.38  15.48  15.08  15.21   26279378
# 2015-01-14  15.07  15.16  14.83  15.11   36798274
# 2015-01-15  15.12  15.16  14.80  14.86   24981340
# 2015-01-16  14.81  15.04  14.75  15.02   32089873
# 2015-01-20  15.08  15.13  14.75  15.01   28553722
# 2015-01-21  14.98  15.11  14.88  14.97   23281464
# 2015-01-22  15.01  15.07  14.90  15.03   23669219
# 2015-01-23  15.02  15.08  14.89  14.91   21620561
# 2015-01-26  14.98  15.15  14.96  15.08   25237196
# 2015-01-27  14.96  14.99  14.72  14.85   34609134
#
# [1275 rows x 5 columns]

# %%
w = np.random.rand(4)
w / w.sum() 
w
# Out:
# array([0.81747559, 0.93329151, 0.61862539, 0.06715794])

# %%
-np.ones((1, 1))
# Out:
# array([[-1.]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <style>
# img{
# display:block;
#     width:100% !important;
# }
# </style>

# %%
a=np.linspace(-1,1,9)
b=np.array([1,2,3,4,5,4,3,2,1])
plt.scatter(a,b)
plt.plot(a,b)
plt.xlim(-1,1)
plt.show()

# %%
import cvxopt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-14abf1b564a4> in <module>()
# ----> 1 import cvxopt
#
# ~\Anaconda3\lib\site-packages\cvxopt\__init__.py in <module>()
#      30 # You should have received a copy of the GNU General Public License
#      31
# ---> 32 import cvxopt.base
#      33
#      34 def normal(nrows, ncols=1, mean=0.0, std=1.0):
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
import numpy as np

# %%
import cvxopt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-14abf1b564a4> in <module>()
# ----> 1 import cvxopt
#
# ~\Anaconda3\lib\site-packages\cvxopt\__init__.py in <module>()
#      30 # You should have received a copy of the GNU General Public License
#      31
# ---> 32 import cvxopt.base
#      33
#      34 def normal(nrows, ncols=1, mean=0.0, std=1.0):
#
# ImportError: DLL load failed: The specified module could not be found.
