# %%
import ccxt
import pandas as pd

kraken = ccxt.kraken({
    'apiKey': 'HE4JSPoApgKjeGEkFfp9BdC1oB8y8TZJGyyy',
    'secret': '5C+arBvOogTCDoKhcTYUPK8BBPy67D',
    'verbose': True
})
pd.DataFrame(kraken.load_markets())
# Out:
# Request: GET https://api.kraken.com/0/public/AssetPairs {'Accept-Encoding': 'gzip, deflate', 'User-Agent': 'python-requests/2.14.2'} None
#
# ...

# %%
kraken.fetchBalance()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-2-c08d392ad581> in <module>()
# ----> 1 kraken.fetchBalance()
#
# ~\Anaconda3\lib\site-packages\ccxt\kraken.py in fetch_balance(self, params)
#     571     def fetch_balance(self, params={}):
#     572         self.load_markets()
# --> 573         response = self.privatePostBalance()
#     574         balances = response['result']
#     575         result = {'info': balances}
#
# ~\Anaconda3\lib\site-packages\ccxt\kraken.py in request(self, path, api, method, params, headers, body)
#     830
#     831     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# --> 832         response = self.fetch2(path, api, method, params, headers, body)
#     833         if not isinstance(response, basestring):
#     834             if 'error' in response:
#
# ...

# %%
# -*- coding: utf-8 -*-

import os
import sys



import ccxt  # noqa: E402

kraken = ccxt.kraken()

#df= pd.DataFrame(kraken.fetchTicker('BTC/USD'))[['ask','bid','datetime','high','last','low','symbol','timestamp','vwap']]
df= kraken.fetchTicker('BTC/USD')
df.pop('info')
df
# Out:
# {'ask': 10031.2,
#  'average': None,
#  'baseVolume': 15986.87540788,
#  'bid': 10010.9,
#  'change': None,
#  'close': None,
#  'datetime': '2018-03-08T11:28:34.170Z',
#  'first': None,
#  'high': 10723.8,
#  'last': 10031.3,
#  'low': 9388.1,
#  'open': 9903.0,
#  'percentage': None,
#  'quoteVolume': 158913884.5489005,
#  'symbol': 'BTC/USD',
#  'timestamp': 1520508514170,
#  'vwap': 9940.27166}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined
