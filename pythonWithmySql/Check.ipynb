# %%
import ccxt
import pandas as pd
import numpy as np

# %%
bitfinex   = ccxt.bitfinex({
    'apiKey': 'hdPHGGOYKaKAR2BDWF7l4J6YJCBYrJGi9H8YJYfht4A ',
    'secret': 'Pc7cKpsoohDXF8EAx3VjkoWE8NJPAjwvVPSVRDXVnrn',
});

# %%
bitfinex   = ccxt.bitfinex({
    'apiKey': 'hdPHGGOYKaKAR2BDWF7l4J6YJCBYrJGi9H8YJYfht4A ',
    'secret': 'Pc7cKpsoohDXF8EAx3VjkoWE8NJPAjwvVPSVRDXVnrn',
})
kraken = ccxt.kraken({
    'apikey': 'HE4JSPoApgKjeGEkFfp9BdC1oB8y8TZJGyyy/8EWAzyjUIX60Bvz3xkO',
    'secret': '5C+arBvOogTCDoKhcTYUPK8BBPy67D/hq5tgkkdao7oAJXvIjCdwbpCJr3fAUfdPP2O12/q12LnxRsjjTZ8eRw=='
})


quoinex = ccxt.quoinex({
    'apikey':'362191',
    'secret': 'rh1lyIQkX0cyo1+hvihqluVblukpnP4AnW7q2P38s8HHFLbuLd5wlwdujjM/+254foiOdxR0hxlYr5aHfps5Iw=='
})

# %%
def getExchange(exchangValue,symbol,apiKey="",secret=""):
    if apiKey !="" and secret!="":
        exchangValue   = ccxt.exchangValue({
        'apiKey': apiKey,
        'secret': secret})
    else:
         exchangValue   = ccxt.exchangValue()
    
    return exchangValue.loadMarkets().fetchTicker(str(symbol)+'/USD')


getExchange('kraken','ETH','HE4JSPoApgKjeGEkFfp9BdC1oB8y8TZJGyyy/8EWAzyjUIX60Bvz3xkO','5C+arBvOogTCDoKhcTYUPK8BBPy67D/hq5tgkkdao7oAJXvIjCdwbpCJr3fAUfdPP2O12/q12LnxRsjjTZ8eRw==')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-f1ca5969ff38> in <module>()
#      10
#      11
# ---> 12 getExchange('kraken','ETH','HE4JSPoApgKjeGEkFfp9BdC1oB8y8TZJGyyy/8EWAzyjUIX60Bvz3xkO','5C+arBvOogTCDoKhcTYUPK8BBPy67D/hq5tgkkdao7oAJXvIjCdwbpCJr3fAUfdPP2O12/q12LnxRsjjTZ8eRw==')
#
# <ipython-input-61-f1ca5969ff38> in getExchange(exchangValue, symbol, apiKey, secret)
#       1 def getExchange(exchangValue,symbol,apiKey="",secret=""):
#       2     if apiKey !="" and secret!="":
# ----> 3         exchangValue   = ccxt.exchangValue({
#       4         'apiKey': apiKey,
#       5         'secret': secret})
#
# AttributeError: module 'ccxt' has no attribute 'exchangValue'

# %%
import ccxt
import pandas as pd
bitfinex   = ccxt.bitfinex({
    'apiKey': 'hdPHGGOYKaKAR2BDWF7l4J6YJCBYrJGi9H8YJYfht4A ',
    'secret': 'Pc7cKpsoohDXF8EAx3VjkoWE8NJPAjwvVPSVRDXVnrn',
})
d1Max = pd.DataFrame(bitfinex.loadMarkets()['BTC/USD'])
d1Max['info']
bitfinex.fetchTicker('BTC/USD')
bitfinex.fetchTrades('BTC/USD')
bitfinex.fetchOrder(1.00001)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     349             self.logger.debug("%s %s, Response: %s %s %s", method, url, response.status_code, response.headers, self.last_http_response)
# --> 350             response.raise_for_status()
#     351
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     927         if http_error_msg:
# --> 928             raise HTTPError(http_error_msg, response=self)
#     929
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.bitfinex.com/v1/order/status
#
# During handling of the above exception, another exception occurred:
#
# InvalidNonce                              Traceback (most recent call last)
# <ipython-input-8-10c4dd16e7b5> in <module>()
#       9 bitfinex.fetchTicker('BTC/USD')
# ...

# %%
df2 = pd.DataFrame(kraken.loadMarkets())
df2
# Out:
#                                                       BCH/BTC  \
# active                                                   True
# altname                                                BCHXBT
# base                                                      BCH
# darkpool                                                False
# fee_loaded                                              False
# id                                                     BCHXBT
# info        {'fees': [[0, 0.26], [50000, 0.24], [100000, 0...
# limits      {'cost': {'max': None, 'min': 0}, 'amount': {'...
# lot                                                     1e-08
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     BTC
# symbol                                                BCH/BTC
# ...

# %%
df3 = pd.DataFrame(poloniex.loadMarkets())
df3
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     349             self.logger.debug("%s %s, Response: %s %s %s", method, url, response.status_code, response.headers, self.last_http_response)
# --> 350             response.raise_for_status()
#     351
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     927         if http_error_msg:
# --> 928             raise HTTPError(http_error_msg, response=self)
#     929
#
# HTTPError: 403 Client Error: Forbidden for url: https://poloniex.com/public?command=returnTicker
#
# During handling of the above exception, another exception occurred:
#
# ExchangeNotAvailable                      Traceback (most recent call last)
# <ipython-input-64-779737769f83> in <module>()
# ...

# %%
df4 = pd.DataFrame(quoinex.loadMarkets())
df4['BTC/USD']

# %%
ccxt.quoinex.la

# %%
ccxt.poloniex.substituteCommonCurrencyCodes

# %%
bitfinex.load_markets

# %%
kraken.fetch_balance()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-65-72c64a691a62> in <module>()
#       1
# ----> 2 kraken.fetch_balance()
#
# ~\Anaconda3\lib\site-packages\ccxt\kraken.py in fetch_balance(self, params)
#     571     def fetch_balance(self, params={}):
#     572         self.load_markets()
# --> 573         response = self.privatePostBalance()
#     574         balances = response['result']
#     575         result = {'info': balances}
#
# ~\Anaconda3\lib\site-packages\ccxt\kraken.py in request(self, path, api, method, params, headers, body)
#     830
#     831     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# --> 832         response = self.fetch2(path, api, method, params, headers, body)
#     833         if not isinstance(response, basestring):
#     834             if 'error' in response:
#
# ...

# %%
import ccxt  # noqa: E402
import time
kraken = ccxt.kraken({ 
    'apiKey': "HE4JSPoApgKjeGEkFfp9BdC1oB8y8TZJGyyy/8EWAzyjUIX60Bvz3xkO",    
    'secret': "5C+arBvOogTCDoKhcTYUPK8BBPy67D/hq5tgkkdao7oAJXvIjCdwbpCJr3fAUfdPP2O12/q12LnxRsjjTZ8eRw==",    
    'verbose': False,  # switch it to False if you don't want the HTTP log
    'nonce': lambda: int(time.time() * 1000)
})

# %%
#my_trades = kraken.fetchMyTrades()
print (kraken.fetch_balance ())
# Out:
# ---------------------------------------------------------------------------
# InvalidNonce                              Traceback (most recent call last)
# <ipython-input-18-400fbd9b1a2d> in <module>()
#       1 #my_trades = kraken.fetchMyTrades()
# ----> 2 print (kraken.fetch_balance ())
#
# ~\Anaconda3\lib\site-packages\ccxt\kraken.py in fetch_balance(self, params)
#     571     def fetch_balance(self, params={}):
#     572         self.load_markets()
# --> 573         response = self.privatePostBalance()
#     574         balances = response['result']
#     575         result = {'info': balances}
#
# ~\Anaconda3\lib\site-packages\ccxt\kraken.py in request(self, path, api, method, params, headers, body)
#     830
#     831     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# --> 832         response = self.fetch2(path, api, method, params, headers, body)
#     833         if not isinstance(response, basestring):
# ...

# %% [raw]
# const exchangeBinance = new ccxt.binance();
# const symbolBinance = 'BTC/USDT';
# exchangeBinance.apiKey = '123';
# exchangeBinance.secret = '123';
# exchangeBinance.fetchTicker(symbolBinance).then(ticker => {
# var task = req.body;
# task['BTCTimestampBinance'] = ticker['timestamp']        task['BTCLastPriceBinance'] = ticker['info']['lastPrice']        }).catch((err) => {            console.log(err);        })
